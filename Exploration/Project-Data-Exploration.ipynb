# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
projects = pd.read_csv('../Data/opendata_projects000.gz', escapechar='\\', names=['_projectid', '_teacher_acctid', '_schoolid', 'school_ncesid', 'school_latitude', 'school_longitude', 'school_city', 'school_state', 'school_zip', 'school_metro', 'school_district', 'school_county', 'school_charter', 'school_magnet', 'school_year_round', 'school_nlns', 'school_kipp', 'school_charter_ready_promise', 'teacher_prefix', 'teacher_teach_for_america', 'teacher_ny_teaching_fellow', 'primary_focus_subject', 'primary_focus_area' ,'secondary_focus_subject', 'secondary_focus_area', 'resource_type', 'poverty_level', 'grade_level', 'vendor_shipping_charges', 'sales_tax', 'payment_processing_charges', 'fulfillment_labor_materials', 'total_price_excluding_optional_support', 'total_price_including_optional_support', 'students_reached', 'total_donations', 'num_donors', 'eligible_double_your_impact_match', 'eligible_almost_home_match', 'funding_status', 'date_posted', 'date_completed', 'date_thank_you_packet_mailed', 'date_expiration'])
projects
# Out:
#                                _projectid                   _teacher_acctid  \
# 0        7342bd01a2a7725ce033a179d22e382d  5c43ef5eac0f5857c266baa1ccfa3d3f
# 1        ed87d61cef7fda668ae70be7e0c6cebf  1f4493b3d3fe4a611f3f4d21a249376a
# 2        b56b502d25666e29550d107bf7e17910  57426949b47700ccf62098e1e9b0220c
# 3        016f03312995d5c89d6b348be4682166  9c0aa56b63b743454d6da9effcf122fc
# 4        cf6275558534ca1b276b0d8d5130dd9a  1d4d8a42730dbb66af1ebb6ab37456b7
# 5        0b8a4f8eb1822ab6dd5cd9ffb918ece3  e5d28482308e2007992ae8b358b31bce
# 6        d25a7dd645bdfb4d702f177cef5e0d8e  0c2d4535f03991165dc72092840d672b
# 7        0b9607c9d3deb8b493653ed4f998fc38  454840ad7f58f2486203f73ee78ea2d5
# 8        e24d8bb3d268a7c837077fa07c153063  0c2d4535f03991165dc72092840d672b
# 9        0d97d7543a766a07b3acf2c732844e85  d41b22314bd46c30150e50c4c78bc128
# 10       eb886a0ef1f498eb88f774947d3d02d7  b55921c6a3999b1f63e6ef69966b79aa
# ...

# %%
projects.columns
# Out:
# Index(['_projectid', '_teacher_acctid', '_schoolid', 'school_ncesid',
#        'school_latitude', 'school_longitude', 'school_city', 'school_state',
#        'school_zip', 'school_metro', 'school_district', 'school_county',
#        'school_charter', 'school_magnet', 'school_year_round', 'school_nlns',
#        'school_kipp', 'school_charter_ready_promise', 'teacher_prefix',
#        'teacher_teach_for_america', 'teacher_ny_teaching_fellow',
#        'primary_focus_subject', 'primary_focus_area',
#        'secondary_focus_subject', 'secondary_focus_area', 'resource_type',
#        'poverty_level', 'grade_level', 'vendor_shipping_charges', 'sales_tax',
#        'payment_processing_charges', 'fulfillment_labor_materials',
#        'total_price_excluding_optional_support',
#        'total_price_including_optional_support', 'students_reached',
#        'total_donations', 'num_donors', 'eligible_double_your_impact_match',
# ...

# %%
completed = projects.loc[projects['funding_status'] == 'completed', :]

# %%
completed['total_price_including_optional_support'].max()

# %%
completed['num_donors'].value_counts()
# Out:
# 1      146935
# 2      133008
# 3       98199
# 4       78862
# 5       64330
# 6       51550
# 7       41891
# 8       33811
# 9       26210
# 10      20746
# 11      16863
# 12      13285
# 13      10895
# 14       8788
# 15       7158
# 16       5760
# 17       4837
# 18       4052
# 19       3337
# 20       2965
# 21       2486
# 22       2140
# 23       1893
# 24       1575
# 25       1502
# 26       1246
# 27       1153
# 28        951
# 29        910
# 30        839
#         ...
# 116         2
# 114         2
# 131         1
# 210         1
# 196         1
# 521         1
# 197         1
# 204         1
# 313         1
# 184         1
# 221         1
# 232         1
# 237         1
# 256         1
# 307         1
# 193         1
# 169         1
# 182         1
# 173         1
# 166         1
# 598         1
# 156         1
# 107         1
# 151         1
# 145         1
# 139         1
# 138         1
# 136         1
# 135         1
# 848         1
# ...

# %%
completed['primary_focus_area'].value_counts()

# %%
#Number of Successful and Failed campaigns
projects['funding_status'].value_counts()
# Out:
# completed      797071
# expired        333630
# live            63500
# reallocated      9086
# Name: funding_status, dtype: int64

# %%
under2000 = projects.loc[projects['total_price_excluding_optional_support']<=2000]
under2000['total_price_excluding_optional_support'].hist()

# %%
under1000 = projects.loc[projects['students_reached'] <= 1000]
under1000.hist(['students_reached'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001DE02B09C50>]],
#       dtype=object)

# %%
total_donations = projects.loc[projects['total_donations']<= 2000]
total_donations['total_donations'].hist()

# %%
donors = projects.loc[projects['num_donors'] <= 50]
donors['num_donors'].hist()

# %%
projects['eligible_double_your_impact_match'].value_counts()
# Out:
# f    921091
# t    282196
# Name: eligible_double_your_impact_match, dtype: int64

# %%
projects['eligible_almost_home_match'].value_counts()
# Out:
# f    1153745
# t      49542
# Name: eligible_almost_home_match, dtype: int64

# %%
projects['teacher_teach_for_america'].value_counts()
# Out:
# f    1151898
# t      51389
# Name: teacher_teach_for_america, dtype: int64

# %%
projects['teacher_ny_teaching_fellow'].value_counts()
# Out:
# f    1188860
# t      14427
# Name: teacher_ny_teaching_fellow, dtype: int64

# %%
projects['primary_focus_area'].value_counts()
# Out:
# Literacy & Language    508084
# Math & Science         326323
# Music & The Arts       105410
# Applied Learning        80312
# Special Needs           78884
# Health & Sports         53519
# History & Civics        50709
# Name: primary_focus_area, dtype: int64

# %%
projects['primary_focus_subject'].value_counts()
# Out:
# Literacy                 339802
# Mathematics              173774
# Literature & Writing     143776
# Special Needs             78884
# Applied Sciences          63736
# Visual Arts               53958
# Environmental Science     49418
# Health & Life Science     39395
# Music                     34807
# Health & Wellness         27535
# History & Geography       26292
# Early Development         24538
# Other                     20447
# Performing Arts           16645
# ESL                       15835
# Character Education       14601
# Social Sciences           14392
# Gym & Fitness             14153
# College & Career Prep     11652
# Team Sports                9276
# Foreign Languages          8671
# Extracurricular            4984
# Civics & Government        4072
# Economics                  3077
# Financial Literacy         2876
# Nutrition                  2555
# Community Service          2493
# Parent Involvement         1597
# Name: primary_focus_subject, dtype: int64

# %%
projects['secondary_focus_area'].value_counts()
# Out:
# Literacy & Language    290582
# Math & Science         203252
# Applied Learning       112301
# History & Civics        61635
# Music & The Arts        57053
# Special Needs           52137
# Health & Sports         42741
# Name: secondary_focus_area, dtype: int64

# %%
projects['school_charter'].value_counts()
# Out:
# f    1098518
# t     104769
# Name: school_charter, dtype: int64

# %%
projects['school_magnet'].value_counts()
# Out:
# f    1099244
# t     104043
# Name: school_magnet, dtype: int64

# %%
projects['grade_level'].value_counts()
# Out:
# Grades PreK-2    456098
# Grades 3-5       381101
# Grades 6-8       202793
# Grades 9-12      163232
# Name: grade_level, dtype: int64

# %%
projects['school_year_round'].value_counts()
# Out:
# f    1184563
# t      18724
# Name: school_year_round, dtype: int64

# %%
projects['poverty_level'].value_counts()
# Out:
# highest poverty     703303
# high poverty        298867
# moderate poverty    167431
# low poverty          33686
# Name: poverty_level, dtype: int64

# %%
projects['resource_type'].value_counts()
# Out:
# Supplies      445719
# Technology    395084
# Books         223562
# Other         122283
# Trips          14185
# Visitors        2402
# Name: resource_type, dtype: int64

# %%
'school_charter', 'school_magnet', 'school_year_round', 'school_nlns', 'school_kipp', 'school_charter_ready_promise', 'teacher_teach_for_america', 'teacher_ny_teaching_fellow', 'eligible_double_your_impact_match', 'eligible_almost_home_match', 'school_metro', 'teacher_prefix', 'primary_focus_subject', 'primary_focus_area', 'secondary_focus_subject', 'secondary_focus_area', 'resource_type', 'poverty_level', 'grade_level'

# %%
projects['school_metro'].isna().sum()
# Out:
# 143595

# %%
projects['teacher_prefix'].isna().sum()
# Out:
# 46

# %%
projects['primary_focus_subject'].isna().sum()
# Out:
# 46

# %%
projects['secondary_focus_subject'].isna().sum()
# Out:
# 383586

# %%
projects['primary_focus_area'].isna().sum()
# Out:
# 46

# %%
projects['secondary_focus_area'].isna().sum()
# Out:
# 383586

# %%
projects['resource_type'].isna().sum()
# Out:
# 52

# %%
projects['grade_level'].isna().sum()
# Out:
# 63

# %%
projects['school_metro'].value_counts()
# Out:
# urban       603165
# suburban    340708
# rural       115819
# Name: school_metro, dtype: int64

# %%
projects['teacher_prefix'].value_counts()
# Out:
# Mrs.          599730
# Ms.           451374
# Mr.           145351
# Teacher         6545
# Dr.              239
# Mr. & Mrs.         2
# Name: teacher_prefix, dtype: int64
